# %% [markdown]
# ## 1. Noțiuni introductive

# %% [markdown]
# ### Următoarele întrebări se referă la certificatul digital al site-ului facultății [3]:
#
# Cine a emis certificatul digital?
#
#         Internet Security Research Group (ISRG)
#
# Care este validitatea certificatului?
#
#         De la Sat, 25 Dec 2021 01:26:58 GMT pana la Fri, 25 Mar 2022 01:26:57 GMT
#
# Pe câți biți este definită cheia publică?
#
#         2048 biti
#
# Care este valoarea exponenților de criptare din certificat și din certificatele care îl atestă în lanț? Ce observați? Are aceasta impact asupra securității?
#
#         Majoritatea certificatelor au exponenții de 65537. Nu are impact asupra securității.

# %% [markdown]
# ## 2. Generarea cheilor folosind Putty

# %% [markdown]
# Folosiți Putty [4] pentru generarea cheilor SSH:
# a) Descărcați puttygen.exe [4].
#
# b) Generați o pereche de chei cheie publică - cheie privată RSA pe 2048 de biți. Apăsați Generate.
#
# c) Adaugati PassPhrase. La ce folosește aceasta?
#
# d) Exportați  cheia  publică  în  fișierul  publick_key.pub,  cheia  secretă  în  fișierul
# private_key.ppk. Pentru aceasta, folositi Save public key, respectiv Save private key.
#
#         ---- BEGIN SSH2 PUBLIC KEY ----
#         Comment: "rsa-key-20220116"
#         AAAAB3NzaC1yc2EAAAADAQABAAABAQCreffekudTSJm0TzC+4nVmK4ONSlBTgSve
#         ut1lM4p8fAMjFMZOL6t1amyu5oGkj8++V+0BGXAbMhR5UX1H7swCEOW7o8wdSDzQ
#         nI392K6fHak5KAms5p/BMXL3RnKBWgRdri5migIkxu6iyhNdLDv9CqzmNf3oVEGj
#         VJcenETN7GsuePIIwlMLllpkKZ9cjjMlUimtKFvSqgyKj2V9kDxFelnnGsAN2L5B
#         UMGLCI4KQ0VSpy78ZrsMMlzxjJ/Czsu/s9NIDbSYKGu+mwrQNf0xpEjPnQCbLJHa
#         RdxwR2zSKAHSLXH8cQeZRzpDB19xoqDnZKHUzYsiOfQTXjE/9G+j
#         ---- END SSH2 PUBLIC KEY ----
#
#         PuTTY-User-Key-File-3: ssh-rsa
#         Encryption: aes256-cbc
#         Comment: rsa-key-20220116
#         Public-Lines: 6
#         AAAAB3NzaC1yc2EAAAADAQABAAABAQCreffekudTSJm0TzC+4nVmK4ONSlBTgSve
#         ut1lM4p8fAMjFMZOL6t1amyu5oGkj8++V+0BGXAbMhR5UX1H7swCEOW7o8wdSDzQ
#         nI392K6fHak5KAms5p/BMXL3RnKBWgRdri5migIkxu6iyhNdLDv9CqzmNf3oVEGj
#         VJcenETN7GsuePIIwlMLllpkKZ9cjjMlUimtKFvSqgyKj2V9kDxFelnnGsAN2L5B
#         UMGLCI4KQ0VSpy78ZrsMMlzxjJ/Czsu/s9NIDbSYKGu+mwrQNf0xpEjPnQCbLJHa
#         RdxwR2zSKAHSLXH8cQeZRzpDB19xoqDnZKHUzYsiOfQTXjE/9G+j
#         Key-Derivation: Argon2id
#         Argon2-Memory: 8192
#         Argon2-Passes: 21
#         Argon2-Parallelism: 1
#         Argon2-Salt: 77a045a3382375cd5bdf5f5ac6a14661
#         Private-Lines: 14
#         7CeDwTEiBsTlw+psFZeqcBVsHRyIPrRtbJK91PADQyhsJWD9iRphA2hR0ZMcQEeQ
#         WgWG1+TaC+lHQzM3p2fkG4N9l+DkTRxHDxFmq2zDWKB7aE3XWD4ZSSnpZT1GtkVD
#         vuLw1BKHgzFAL7Suhi+XaDqPtxzLGAixlxFObYNiAf/5Dj5S/mSXE9JHr5Tqe+qP
#         AUFqAXlKt/NINR/8hlCuvcWvjEtqSwa4PbhEwvrkkDaH0bNj+a0fTDGafhEhdeRI
#         /4ARjxGkRv4SmXUkSm1EchuM5DssCJr280K1n5O+F1kkpZ1sQ2s4+6athTVSt+aI
#         aqQswpJaWbNcC6So85VfhdMbvzHoob30NdxMON8ANxBL9KaOyHbSerYxdo6P7pTP
#         rAwuJl7MDEBvSBCJ0GMJ3pqhCh8W/+joEtpLlsL6FOCTsTD3H7nu5ifaG5xmDIkG
#         bGIfUVMxlblCh5/iaC7ej8p5OX9Vjb7Ve/4hEOC7zmH8x+P/tf7RLz62h8Q2zHcx
#         5CtwqhuUcfsGsTgPdWBIkSNhnBvCQNRCqRtIxlzcKg25ts1AEqsttV5Llefmbm7d
#         46SVVnc4Luz1wDtxOX2ZeXlLhmIGL6u3FYTFeIOJZiWsoTw43Yi4w1At4rEli9Vj
#         Dnuz+wKl3znbwPdTQ2ZE/3wX2I5E3j4YtbQRPVjgGrjKC8PFZg3SSaAx3CK7Jjv7
#         ++Lh1qZKhMuk60jmvP88kI0o1rTsneO9AABiXny6WAqvF2tBjgiXTEnwOIC9GfHN
#         NAQAHgUQINEW1DNVDOABKPSys2OUCLD55sCgk7Mlsm4mAtXklwWjBbPTkcZomnhM
#         0j4QBKPF1ONKF3kgJeHWrNGZ2+EmUBfeY3Ovx45KgYEh9S8FPs7Ud14KHPquIJr1
#         -----END RSA PRIVATE KEY-----
#
# f) Deschideți și vedeți ce conțin toate fișierele generate.

# %% [markdown]
# ## 3. Generarea certificatelor cu OpenSSL

# %% [markdown]
# ## Răspundeți la următoarele cerințe folosind OpenSSL [5]:
# a) Generați o cheie RSA. Revedeți laboratorul de criptare asimetrică dacă nu vă mai amintiți cum realizați acest lucru.
#
# b) Folosiți cheia generată anterior într-un certificat self-signed, valabil 120 de zile,
# stocat ca ca.crt. Folosiți următoarele informații:
#
# Country: RO
# Provincie: Muntenia
# Localitate: Bucuresti
# Numele organizatiei: CA_SSI
# Numele unitatii:CA_SSI_Lab
# Common Name: CA_Andrei
# E-mail: test@test.ro
#
# Pentru aceasta, folositi comanda
#  openssl req -new -x509 - days <days> -key <key> -out ca.crt
#
# c) Citiți despre standardul X.509 [6]. Vizualizați certificatul digital creat:
#  openssl x509 -text -noout -in ca.crt
#
# d) Folosiți acest certificat al CA ca să semnați/emiteți un alt certificat al unei entitati
# subordonate SUB_SLA. Folositi urmatoarele informatii:
#
# Country: RO
# Provincie: Muntenia
# Localitate: Bucuresti
# Numele organizatiei: SUB_SSI
# Numele unitatii:SUB_SSI_Lab
# Common Name: SUB_numele vostru (e.g.: CA_Andrei)
# E-mail: test_sub@test.ro
#
# Pentru aceasta, mai întâi generați o noua cheie a entității SUB_SSI pe 2048 de biți
# in fișierul sub.key.
#
# e) Inițiați un Certificate Signing Request (CSR) sub.csr:
#
# openssl req -new -key sub.key -out sub.csr
#
# f) Creați apoi un certificat pentru SUB_SSI sub.crt semnat de autoritatea CA, valabil
# pentru 60 de zile, cu numărul serial 02:
#
# openssl x509 -req -days <days> -in sub.csr -CA <ceritificat_CA> -
# CAkey <ca_key> -set_serial <serial_no> -out sub.crt
#
# g) Vizualizați certificatul digital creat:
#
# openssl x509 -text -noout -in sub.crt
#
# h) Transformați acest certificat digital in PKCS#12:
#   openssl pkcs12 -export -out sub.p12 -inkey sub.key -in sub.crt -
# chain -CAfile ca.crt
#
# i) Verificați conținutul fișierului sub.p12 folosind:
#
# openssl pkcs12 -info -in sub.p12
